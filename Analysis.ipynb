# %%
# For data analysis
import numpy as np
import pandas as pd

#For navigating directories
import os

#For graphing
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#Statistics
from scipy.stats import gaussian_kde

# %%
mpeg_exos = pd.read_csv("mpeg_exos.csv")
cd44_exos = pd.read_csv("cd44_exos.csv")

# %%
cd44_results = pd.read_csv("cd44_results.csv")

# %%
cd44_exos.shape
# Out:
# (2552, 25)

# %%
mpeg_exos.shape
# Out:
# (1488, 25)

# %%
fig, ax = plt.subplots(figsize=(15,10))
x = np.linspace(0,8,801)
ax.hist(mpeg_exos.biomarker_log_intensity,density=True,bins="fd",
        color="blue",edgecolor="black",alpha=0.5)
ax.hist(cd44_exos.biomarker_log_intensity,density=True,bins="fd",
        color="red",edgecolor="black",alpha=0.5)

ax.plot(x,mpeg_pdf,color="black")
ax.plot(x,cd44_pdf,color="black")

ax.set_xlabel("Log-Intensity",fontsize=22)
ax.set_ylabel("Density",fontsize=22)
ax.tick_params(axis='x', labelsize= 20)
ax.tick_params(axis='y', labelsize= 20)
